# %% [markdown]
# Connection to mysql

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="127.0.0.1",
    port=3307,
    user="sadop_user",
    password="1234"
)

cursor = conn.cursor()
print("Connected as sadop_user")
# Out:
# Connected as sadop_user

# %%
cursor.execute("drop database sadop_db")
cursor.execute("CREATE DATABASE IF NOT EXISTS sadop_db")
cursor.execute("USE sadop_db")
print("Database selected")

# %% [markdown]
# Users Tabel

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS Users (
    user_id INT AUTO_INCREMENT PRIMARY KEY,
    name VARCHAR(100) NOT NULL,
    email VARCHAR(100) UNIQUE NOT NULL,
    phone VARCHAR(20),
    created_at DATETIME DEFAULT CURRENT_TIMESTAMP
)
""")

# %% [markdown]
# Accounts table

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS Accounts (
    account_id INT AUTO_INCREMENT PRIMARY KEY,
    user_id INT NOT NULL,
    type ENUM('savings','checking') DEFAULT 'checking',
    balance DECIMAL(12,2) DEFAULT 0,
    created_at DATETIME DEFAULT CURRENT_TIMESTAMP,
    FOREIGN KEY (user_id) REFERENCES Users(user_id)
)
""")

# %% [markdown]
# Transactions table

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS Transactions (
    transaction_id INT AUTO_INCREMENT PRIMARY KEY,
    account_id INT NOT NULL,
    amount DECIMAL(12,2) NOT NULL,
    type ENUM('debit','credit') NOT NULL,
    timestamp DATETIME DEFAULT CURRENT_TIMESTAMP,
    FOREIGN KEY (account_id) REFERENCES Accounts(account_id)
)
""")

# %% [markdown]
# log table

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS Logs (
    log_id INT AUTO_INCREMENT PRIMARY KEY,
    account_id INT,
    action VARCHAR(255),
    query_time FLOAT,
    timestamp DATETIME DEFAULT CURRENT_TIMESTAMP,
    FOREIGN KEY (account_id) REFERENCES Accounts(account_id)
)
""")

# %% [markdown]
# Commit & Verify

# %%
conn.commit()

cursor.execute("SHOW TABLES")
print(cursor.fetchall())

# %%
pip install Faker
# Out:
# Collecting Faker
#   Downloading faker-38.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tzdata in c:\users\pc\anaconda3\envs\sadop\lib\site-packages (from Faker) (2025.3)
# Downloading faker-38.2.0-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 233.0 kB/s eta 0:00:07
#    ---------- ----------------------------- 0.5/2.0 MB 233.0 kB/s eta 0:00:07
#    --------------- ------------------------ 0.8/2.0 MB 342.4 kB/s eta 0:00:04
#    --------------- ------------------------ 0.8/2.0 MB 342.4 kB/s eta 0:00:04
#    --------------------- ------------------ 1.0/2.0 MB 423.0 kB/s eta 0:00:03
#    --------------------- ------------------ 1.0/2.0 MB 423.0 kB/s eta 0:00:03
#    -------------------------- ------------- 1.3/2.0 MB 424.9 kB/s eta 0:00:02
#    -------------------------- ------------- 1.3/2.0 MB 424.9 kB/s eta 0:00:02
#    ------------------------------------- -- 1.8/2.0 MB 550.1 kB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 581.9 kB/s  0:00:03
# Installing collected packages: Faker
# Successfully installed Faker-38.2.0
# Note: you may need to restart the kernel to use updated packages.
