# %% [markdown]
# # 1. Data Pipeline for AI

# %% [markdown]
# ## 1.1 Load Performance Metrics Dataset

# %%
import pandas as pd

metrics_path = r"C:\Users\pc\data science\SADOP\data\slow_query_metrics.csv"
df = pd.read_csv(metrics_path)

print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (20000, 10)
#                                                query  query_time  \
# 0  SELECT AVG(total_amount)\nFROM (\n    SELECT S...    0.641623
# 1  SELECT u.user_id, t.transaction_date, t.amount...    1.644557
# 2  SELECT AVG(total_amount)\nFROM (\n    SELECT S...    0.650696
# 3  SELECT u.user_id, COUNT(t.transaction_id) AS t...    0.620023
# 4  SELECT DISTINCT u.user_id\nFROM user u\nJOIN a...    0.347722
#
#    rows_returned  has_sum  has_group_by  has_where  tables_count  \
# 0              1        1             1          0             2
# 1         250000        0             0          0             3
# 2              1        1             1          0             2
# 3          16520        0             1          1             3
# 4          16329        0             0          1             3
#
#    query_length  cpu_usage  memory_usage
# 0           178        0.0      0.746455
# 1           185       12.5      1.108117
# 2           178        0.0      0.763426
# 3           200        0.0      0.764052
# 4           152        0.0      0.768193

# %% [markdown]
# ## 1.2 Inspect Feature Distributions

# %%
df.describe()
# Out:
#          query_time  rows_returned      has_sum  has_group_by     has_where  \
# count  20000.000000   20000.000000  20000.00000  20000.000000  20000.000000
# mean       2.460381   42186.366850      0.24755      0.370650      0.562200
# std      128.639992   75246.922883      0.43160      0.482991      0.496128
# min        0.000000       0.000000      0.00000      0.000000      0.000000
# 25%        0.099602    3052.000000      0.00000      0.000000      0.000000
# 50%        0.574728   16520.000000      0.00000      0.000000      1.000000
# 75%        0.846677   25143.000000      0.00000      1.000000      1.000000
# max    18149.735816  250000.000000      1.00000      1.000000      1.000000
#
#        tables_count  query_length     cpu_usage  memory_usage
# count  20000.000000  20000.000000  20000.000000  20000.000000
# mean       2.254600    157.014750      7.918920      1.385129
# std        0.908251     54.007287     16.800883      0.104171
# min        1.000000     45.000000      0.000000      0.746455
# 25%        1.000000    148.000000      0.000000      1.345806
# 50%        2.000000    181.000000      0.000000      1.401846
# 75%        3.000000    196.000000     12.500000      1.462074
# max        4.000000    225.000000    100.000000      1.917593

# %% [markdown]
# ## 11.3 Define ML Features

# %%
# Select features
FEATURE_COLUMNS = [
    "query_time",
    "rows_returned",
    "has_sum",
    "has_group_by",
    "has_where",
    "tables_count",
    "query_length",
    "cpu_usage",
    "memory_usage"
]

X = df[FEATURE_COLUMNS]
X.describe()
# Target variable
# Out:
#          query_time  rows_returned      has_sum  has_group_by     has_where  \
# count  20000.000000   20000.000000  20000.00000  20000.000000  20000.000000
# mean       2.460381   42186.366850      0.24755      0.370650      0.562200
# std      128.639992   75246.922883      0.43160      0.482991      0.496128
# min        0.000000       0.000000      0.00000      0.000000      0.000000
# 25%        0.099602    3052.000000      0.00000      0.000000      0.000000
# 50%        0.574728   16520.000000      0.00000      0.000000      1.000000
# 75%        0.846677   25143.000000      0.00000      1.000000      1.000000
# max    18149.735816  250000.000000      1.00000      1.000000      1.000000
#
#        tables_count  query_length     cpu_usage  memory_usage
# count  20000.000000  20000.000000  20000.000000  20000.000000
# mean       2.254600    157.014750      7.918920      1.385129
# std        0.908251     54.007287     16.800883      0.104171
# min        1.000000     45.000000      0.000000      0.746455
# 25%        1.000000    148.000000      0.000000      1.345806
# 50%        2.000000    181.000000      0.000000      1.401846
# 75%        3.000000    196.000000     12.500000      1.462074
# max        4.000000    225.000000    100.000000      1.917593

# %% [markdown]
# ## 11.4 Create Performance Labels

# %%
SLOW_QUERY_THRESHOLD = 1

df["is_slow"] = (df["query_time"] >= SLOW_QUERY_THRESHOLD).astype(int)

y = df["is_slow"]

df[["query_time", "is_slow"]].head()
# Out:
#    query_time  is_slow
# 0    0.641623        0
# 1    1.644557        1
# 2    0.650696        0
# 3    0.620023        0
# 4    0.347722        0

# %% [markdown]
# ## 11.5 Check Class Balance

# %%
df["is_slow"].value_counts(normalize=True)
# Out:
# is_slow
# 0    0.7786
# 1    0.2214
# Name: proportion, dtype: float64

# %%
df
# Out:
#                                                    query  query_time  \
# 0      SELECT AVG(total_amount)\nFROM (\n    SELECT S...    0.641623
# 1      SELECT u.user_id, t.transaction_date, t.amount...    1.644557
# 2      SELECT AVG(total_amount)\nFROM (\n    SELECT S...    0.650696
# 3      SELECT u.user_id, COUNT(t.transaction_id) AS t...    0.620023
# 4      SELECT DISTINCT u.user_id\nFROM user u\nJOIN a...    0.347722
# ...                                                  ...         ...
# 19995  SELECT u.user_id, SUM(t.amount) AS total_amoun...    0.739858
# 19996  SELECT *\nFROM user u\nWHERE EXISTS (\n    SEL...    0.326831
# 19997    SELECT *\nFROM user\nWHERE email LIKE '%gmail%'    0.013524
# 19998  SELECT user_id FROM user\nUNION\nSELECT user_i...    0.083571
# 19999  SELECT user_id FROM user\nUNION\nSELECT user_i...    0.079103
#
#        rows_returned  has_sum  has_group_by  has_where  tables_count  \
# 0                  1        1             1          0             2
# 1             250000        0             0          0             3
# 2                  1        1             1          0             2
# 3              16520        0             1          1             3
# 4              16329        0             0          1             3
# ...              ...      ...           ...        ...           ...
# 19995          16520        1             1          0             3
# 19996          16437        0             0          1             2
# 19997              0        0             0          1             1
# 19998          20000        0             0          0             1
# 19999          20000        0             0          0             1
#
#        query_length  cpu_usage  memory_usage  is_slow
# 0               176        0.0      0.746455        0
# 1               183       12.5      1.108117        1
# 2               176        0.0      0.763426        0
# 3               198        0.0      0.764052        0
# 4               150        0.0      0.768193        0
# ...             ...        ...           ...      ...
# 19995           196        0.0      1.499314        1
# 19996           181        0.0      1.499314        0
# 19997            45        0.0      1.499314        0
# 19998            59        0.0      1.499314        0
# 19999            59        0.0      1.499314        0
#
# [20000 rows x 11 columns]

# %% [markdown]
# ## 11.6 Save Feature Dataset

# %%
feature_dataset_path = r"C:\Users\pc\data science\SADOP\data\ml_features.csv"
df.to_csv(feature_dataset_path, index=False)

print(f"ML-ready dataset saved to {feature_dataset_path}")
# Out:
# ML-ready dataset saved to C:\Users\pc\data science\SADOP\data\ml_features.csv

# %%
df.describe()
# Out:
#          query_time  rows_returned      has_sum  has_group_by     has_where  \
# count  20000.000000   20000.000000  20000.00000  20000.000000  20000.000000
# mean       2.460381   42186.366850      0.24755      0.370650      0.562200
# std      128.639992   75246.922883      0.43160      0.482991      0.496128
# min        0.000000       0.000000      0.00000      0.000000      0.000000
# 25%        0.099602    3052.000000      0.00000      0.000000      0.000000
# 50%        0.574728   16520.000000      0.00000      0.000000      1.000000
# 75%        0.846677   25143.000000      0.00000      1.000000      1.000000
# max    18149.735816  250000.000000      1.00000      1.000000      1.000000
#
#        tables_count  query_length     cpu_usage  memory_usage       is_slow
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       2.254600    157.014750      7.918920      1.385129      0.410000
# std        0.908251     54.007287     16.800883      0.104171      0.491846
# min        1.000000     45.000000      0.000000      0.746455      0.000000
# 25%        1.000000    148.000000      0.000000      1.345806      0.000000
# 50%        2.000000    181.000000      0.000000      1.401846      0.000000
# 75%        3.000000    196.000000     12.500000      1.462074      1.000000
# max        4.000000    225.000000    100.000000      1.917593      1.000000
