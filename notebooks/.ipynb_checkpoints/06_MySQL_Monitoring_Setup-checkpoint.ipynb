# %%
import mysql.connector
from faker import Faker
import random
from datetime import datetime, timedelta
import pandas as pd
print("All set up")
# Out:
# All set up

# %%
conn = mysql.connector.connect(
    host="127.0.0.1",
    port=3307,
    user="sadop_user",
    password="1234",
    database="sadop_DB"
)
cursor = conn.cursor()
print("Connected to SADOP database")
# Out:
# Connected to SADOP database

# %%
cursor.execute("SHOW VARIABLES LIKE 'slow_query_log';")
print("slow_query_log:", cursor.fetchall())

cursor.execute("SHOW VARIABLES LIKE 'slow_query_log_file';")
print("slow_query_log_file:", cursor.fetchall())

cursor.execute("SHOW VARIABLES LIKE 'long_query_time';")
print("long_query_time:", cursor.fetchall())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cursor.executemany("SHOW VARIABLES LIKE 'slow_query_log'")
#       2 cursor.executemany("SHOW VARIABLES LIKE 'slow_query_log_file'")
#       3 cursor.executemany("SHOW VARIABLES LIKE 'long_query_time'")
#
# TypeError: CMySQLCursor.executemany() missing 1 required positional argument: 'seq_params'
