# %% [markdown]
# # generate data Frame and store them in CSV files

# %%
import mysql.connector
from faker import Faker
import random
from datetime import datetime, timedelta
import pandas as pd
print("All set up")
# Out:
# All set up

# %% [markdown]
# # Connect to MySQL

# %%
conn = mysql.connector.connect(
    host="127.0.0.1",
    port=3307,
    user="sadop_user",
    password="1234",
    database="sadop_DB"
)
cursor = conn.cursor()
print("Connected to SADOP database")
# Out:
# Connected to SADOP database

# %% [markdown]
# ## 4.1 test the connection

# %%
cursor.execute("SELECT * FROM Users LIMIT 10;")
users = cursor.fetchall()
for u in users:
    print(u)
# Out:
# (1, 'Heidi Curtis', 'taralarsen@example.com', '400.279.0261x640', datetime.datetime(2024, 11, 19, 15, 33, 21))
# (2, 'Craig Kelley', 'kevinbell@example.net', '001-799-995-8042', datetime.datetime(2025, 3, 19, 21, 41, 51))
# (3, 'Lisa Boone', 'ophillips@example.net', '(324)739-4975x111', datetime.datetime(2025, 6, 26, 18, 21, 4))
# (4, 'Barbara Thomas', 'changlori@example.com', '795-409-3560', datetime.datetime(2023, 12, 1, 12, 7, 30))
# (5, 'Karen Johnson', 'ashleydavis@example.org', '+1-474-562-7359', datetime.datetime(2025, 5, 23, 23, 23, 18))
# (6, 'Cheryl Kelly', 'rporter@example.com', '001-669-860-3849', datetime.datetime(2023, 2, 18, 22, 44, 2))
# (7, 'Luke Fritz', 'neil65@example.net', '001-824-408-0861x657', datetime.datetime(2024, 11, 30, 14, 37, 37))
# (8, 'Jennifer Rowe', 'austinbarnes@example.org', '923.322.7498x3475', datetime.datetime(2023, 12, 18, 8, 57, 4))
# ...

# %% [markdown]
# ## 4.2 transform the Data tabels in to Data frames

# %%
df_users = pd.read_sql("SELECT * FROM Users LIMIT 10000;", conn)
df_users
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_26780\1010626938.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_users = pd.read_sql("SELECT * FROM Users LIMIT 10000;", conn)
#       user_id               name                      email  \
# 0           1       Heidi Curtis     taralarsen@example.com
# 1           2       Craig Kelley      kevinbell@example.net
# 2           3         Lisa Boone      ophillips@example.net
# 3           4     Barbara Thomas      changlori@example.com
# 4           5      Karen Johnson    ashleydavis@example.org
# ...       ...                ...                        ...
# 9995     9996        Jason Moore   mallorysmith@example.net
# 9996     9997      Angela Taylor    jamesthomas@example.com
# 9997     9998   Stephanie Austin          oreid@example.net
# ...

# %%
df_Accounts = pd.read_sql("SELECT * FROM Accounts LIMIT 19968;", conn)
df_Accounts
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_26780\4282813482.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_Accounts = pd.read_sql("SELECT * FROM Accounts LIMIT 19968;", conn)
#        account_id  user_id      type  balance          created_at
# 0               1      953  checking  6095.10 2025-04-26 13:13:16
# 1               2     6799  checking  9386.34 2024-02-06 15:47:42
# 2               3     6799   savings  2110.29 2023-07-02 10:42:42
# 3               4     5020  checking  1753.93 2023-07-05 05:40:00
# 4               5     5020   savings  6424.18 2025-02-07 12:16:29
# ...           ...      ...       ...      ...                 ...
# 19963       19964      848  checking  5386.29 2024-03-18 09:29:07
# 19964       19965      848  checking  7709.19 2025-12-02 03:28:17
# ...

# %%
df_transactions = pd.read_sql("SELECT * FROM Transactions LIMIT 250200;", conn)
df_transactions
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_26780\4009098552.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_transactions = pd.read_sql("SELECT * FROM Transactions LIMIT 250200;", conn)
#         transaction_id  account_id   amount    type           timestamp
# 0                    1       17120  1657.68   debit 2024-03-11 09:24:22
# 1                    2       17120  1621.52   debit 2025-06-12 01:07:16
# 2                    3       17120   743.62  credit 2024-05-03 18:32:38
# 3                    4       17120  1458.78   debit 2023-12-31 00:18:37
# 4                    5       17120   751.56   debit 2024-12-13 22:42:22
# ...                ...         ...      ...     ...                 ...
# 250183          250184        4217   273.60   debit 2024-07-07 18:40:51
# ...

# %%
df_logs = pd.read_sql("SELECT * FROM Logs LIMIT 80000;", conn)
df_logs
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_26780\411418577.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_logs = pd.read_sql("SELECT * FROM Logs LIMIT 80000;", conn)
#        log_id  account_id               action  query_time           timestamp
# 0           1       17120        balance_check      2.4358 2025-08-22 15:39:10
# 1           2       17120         failed_login      1.8784 2025-04-29 02:57:16
# 2           3       17120               logout      1.4051 2025-02-21 02:11:47
# 3           4       17120        balance_check      0.1209 2024-12-25 01:35:33
# 4           5       17120         failed_login      0.8479 2025-02-04 02:04:00
# ...       ...         ...                  ...         ...                 ...
# 79844   79845        4216               logout      1.5736 2025-10-12 23:01:45
# ...

# %% [markdown]
# ## 4.3 Store the Data frames into CSV files for the ML/RL models

# %%
users_csv_path = r"C:\Users\pc\data science\SADOP\data\users.csv"
df_users.to_csv(users_csv_path, index=False)
print(f"Metrics saved to {users_csv_path}")
# Out:
# Metrics saved to C:\Users\pc\data science\SADOP\data\users.csv

# %%
df_Accounts_csv_path = r"C:\Users\pc\data science\SADOP\data\Accounts.csv"
df_Accounts.to_csv(df_Accounts_csv_path, index=False)
print(f"Metrics saved to {df_Accounts_csv_path}")
# Out:
# Metrics saved to C:\Users\pc\data science\SADOP\data\Accounts.csv

# %%
df_transactions_csv_path = r"C:\Users\pc\data science\SADOP\data\transactions.csv"
df_transactions.to_csv(df_transactions_csv_path, index=False)
print(f"Metrics saved to {df_transactions_csv_path}")
# Out:
# Metrics saved to C:\Users\pc\data science\SADOP\data\transactions.csv

# %%
df_logs_csv_path = r"C:\Users\pc\data science\SADOP\data\logs.csv"
df_logs.to_csv(df_logs_csv_path, index=False)
print(f"Metrics saved to {df_logs_csv_path}")
# Out:
# Metrics saved to C:\Users\pc\data science\SADOP\data\logs.csv
