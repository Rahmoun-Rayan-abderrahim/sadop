# %% [markdown]
# # 5. Database Backup

# %% [markdown]
# ## 5.1 Export Full MySQL Database Backup

# %% [markdown]
# ## 5.2 Locate MySQL mysqldump Tool

# %%
## C:\Program Files\MySQL\MySQL Server 8.0\bin

# %% [markdown]
# ## 5.3 Backup Command (Windows)

# %% [markdown]
# cd "C:\Program Files\MySQL\MySQL Server 8.0\bin"
#
# mysqldump -u sadop_user -p -P 3307 sadop_db > "C:\Users\pc\data science\SADOP\db\sadop_db_backup.sql"
